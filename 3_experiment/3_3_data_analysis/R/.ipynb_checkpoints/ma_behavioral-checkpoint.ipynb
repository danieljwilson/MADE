# %% [markdown]
# # Imports

# %% [markdown]
# ## Libraries

# %%
library(tidyverse)
library(Hmisc) # cut2

library(lme4)
library(lmerTest)
library(emmeans)

# Load helper functions
library(devtools)
source_url("https://raw.githubusercontent.com/hauselin/hausekeep/master/R/summaryh.R")

## set universal plot size:
options(repr.plot.width=7, repr.plot.height=3.5)
# Out:
# Attaching package: ‘emmeans’
#
# The following object is masked from ‘package:devtools’:
#
#     test
#
# SHA-1 hash of file is 34fc41edf700356b68b51826dc27b8f8f876d841

# %% [markdown]
# ## Data

# %% [markdown]
# ### Load
# ---
# Already Cleaned
#
# **++ADD cleaning parameters** to `ma_clean_data` file
#
# ---

# %%
load("../data/swap_v1_clean.RData")
load("../data/swap_v2_clean.RData")

# rename for simplicity
v1 = swap_v1_clean
v2 = swap_v2_clean
# clean up
rm(swap_v1_clean, swap_v2_clean)

v301_long = readRDS("../data/v301_clean.rds")
v302_long = readRDS("../data/v302_clean.rds")

# %%
v301 = v301_long[!duplicated(v301_long[,c("subject","trial")]),]
v302 = v302_long[!duplicated(v302_long[,c("subject","trial")]),]

# %%
# indicate which version the experiment is
v1$version = 'v1'
v2$version = 'v2'
v301$version = 'v301'
v302$version = 'v302'

# %%
print("v1")
head(v1, 3)
print("v2")
head(v2, 3)
print("v3.0.1")
head(v301,3)
print("v3.0.2")
head(v302, 3)
# Out:
# [1] "v1"
#   Trial correct faceVal houseVal mult1House mult2Face summedVal earnings
# 1 1     1       0.66     0.86    2          2          3.04     39.60
# 2 2     0       0.38    -0.52    1          1         -0.14     39.46
# 3 3     1       0.32    -0.68    1          3          0.28     39.74
#   imageList          flip ⋯ 4_fixation 5_fixation 6_fixation 7_fixation
# 1 [1, 0, 1, 0, 1, 0] 2    ⋯ 0.433219   1.233326   2.699835   NA
# 2 [0, 1, 0]          2    ⋯       NA         NA         NA   NA
# 3 [0, 1, 0]          1    ⋯       NA         NA         NA   NA
#   8_fixation 9_fixation 10_fixation 11_fixation 12_fixation 13_fixation
# 1 NA         NA         NA          NA          NA          NA
# 2 NA         NA         NA          NA          NA          NA
# 3 NA         NA         NA          NA          NA          NA
# [1] "v2"
#    choice correct earnings face_mult face_val_base first_image house_mult
# 10 0      1       -10.600  2.0       -0.38         1           0.5
# 11 1      1       -10.306  0.5        0.50         0           0.1
# 13 0      1       -10.646  1.0       -0.40         0           1.0
#    house_val_base image_list   key_entry_list                   ⋯ absSummedVal
# 10 -0.72          [1, 0, 1]    ['space', 'space', 'j']          ⋯ 1.120
# 11  0.44          [0, 1]       ['space', 'f']                   ⋯ 0.294
# 13 -0.78          [0, 1, 0, 1] ['space', 'space', 'space', 'j'] ⋯ 1.180
#    swapAmount firstMult firstVal secondMult secondVal faceTotal houseTotal
# 10 3          0.5       -0.36    2.0        -0.760    -0.76     -0.360
# 11 2          0.5        0.25    0.1         0.044     0.25      0.044
# 13 4          1.0       -0.40    1.0        -0.780    -0.40     -0.780
#    total_0_face total_1_house
# 10 1.6668216    4.616794
# 11 0.9669452    2.850013
# 13 0.9169345    2.099861
# [1] "v3.0.1"
#   date             psychopy_version exp_version face_version house_version left
# 1 2019_Feb_06_1040 3.0.2            3.0.1       1            1             face
# 2 2019_Feb_06_1040 3.0.2            3.0.1       1            1             face
# 3 2019_Feb_06_1040 3.0.2            3.0.1       1            1             face
#   subject block trial rt    ⋯ total_fix_num total_weights_fix total_stim_fix
# 1 1       0     1     1.933 ⋯ 7             4                 3
# 2 1       0     3     1.933 ⋯ 7             4                 3
# 3 1       0     4     1.550 ⋯ 7             4                 3
#   which_fix fix_stim_val_base fix_stim_mult outlier_accuracy_pVal
# 1 0         0                 0             0.3192097
# 2 0         0                 0             0.3192097
# 3 0         0                 0             0.3192097
#   outlier_accuracy_MAD outlier_rt_pVal outlier_rt_MAD
# 1 0.76                 0               1.93
# 2 0.76                 0               1.93
# 3 0.76                 0               1.55
# [1] "v3.0.2"
#   date             psychopy_version exp_version face_version house_version left
# 1 2019_Feb_20_0900 3.0.2            3.0.2       0            1             face
# 2 2019_Feb_20_0900 3.0.2            3.0.2       0            1             face
# 3 2019_Feb_20_0900 3.0.2            3.0.2       0            1             face
#   subject block trial rt    ⋯ total_fix_num total_weights_fix total_stim_fix
# 1 41      0     0     3.467 ⋯ 7             4                 3
# 2 41      0     1     2.050 ⋯ 5             3                 2
# 3 41      0     2     3.867 ⋯ 7             4                 3
#   which_fix fix_stim_val_base fix_stim_mult outlier_accuracy_pVal
# 1 0         0                 0             0.4746895
# 2 0         0                 0             0.4746895
# 3 0         0                 0             0.4746895
#   outlier_accuracy_MAD outlier_rt_pVal outlier_rt_MAD
# 1 0.85                 0               3.47
# 2 0.85                 0               2.05
# 3 0.85                 0               3.87

# %% [markdown]
# ### Format

# %%
# Bin responses by summed val
v1$bin = cut2(v1$summedVal, g=19, levels.mean=TRUE, digits=2)
v2$bin = cut2(v2$summedVal, g=19, levels.mean=TRUE, digits=2)
v301$bin = cut2(v301$summed_val_total, g=19, levels.mean=TRUE, digits=2)
v302$bin = cut2(v302$summed_val_total, g=19, levels.mean=TRUE, digits=2)

# Bin responses by abs val
v1$bin_abs = cut2(abs(v1$summedVal), g=10, levels.mean=TRUE, digits=2)
v2$bin_abs = cut2(abs(v2$summedVal), g=10, levels.mean=TRUE, digits=2)
v301$bin_abs = cut2(abs(v301$summed_val_total), g=10, levels.mean=TRUE, digits=2)
v302$bin_abs = cut2(abs(v302$summed_val_total), g=10, levels.mean=TRUE, digits=2)

# %% [markdown]
# # Psychometrics

# %% [markdown]
# ## RT
# by Abs. Offer Value

# %% [markdown]
# ### Function

# %%
rt_func = function(df){
    subjects = length(unique(df$subject))

    rt = df %>%
        group_by(subject, bin_abs) %>%
        summarise(rt = mean(rt)) %>%
        group_by(bin_abs) %>%
        summarise(N = length(rt),
                  rt_se = sd(rt) / sqrt(subjects),
                  rt = mean(rt)
                 ) %>%
        mutate(bin_abs = round(as.numeric(as.character(bin_abs)), 2))

    #head(rt, 3)
    ggplot(data = rt,aes(x = bin_abs,y = rt)) + 
      geom_point() + 
      #geom_line() +
      geom_errorbar(aes(ymin = rt-rt_se,ymax = rt+rt_se)) + 
      labs(x = "Net Value", y = "Reaction Time (seconds)") +
      theme_minimal() +
      ggtitle("Mean Reaction Time by abs(Net Value)")
    #return(rt)
}

# %% [markdown]
# ### V1

# %%
rt_func(v1)
# Out:
# plot without title

# %% [markdown]
# ### V2

# %%
rt_func(v2)
# Out:
# plot without title

# %% [markdown]
# ### V3.0.1

# %%
rt_func(v301)
# Out:
# plot without title

# %% [markdown]
# ### V3.0.2

# %%
rt_func(v302)
# Out:
# plot without title

# %% [markdown]
# ### V3.1.0

# %% [markdown]
# ### Comparisons

# %%
# clean up
rm(df_all)

# %%
# list of dfs we want tocompare
df.list = list(v1, v2, v301, v302)

# %%
# make df with all versions
for (df in df.list){
    subjects = length(unique(df$subject))
    version = df$version[1]

    temp = df %>%
            group_by(subject, bin_abs) %>%
            summarise(rt = mean(rt)) %>%
            group_by(bin_abs) %>%
            summarise(N = length(rt),
                      rt_se = sd(rt) / sqrt(subjects),
                      rt = mean(rt)
                     ) %>%
            mutate(bin_abs = round(as.numeric(as.character(bin_abs)), 2),
                  version = version)
    
    if(!exists("df_all")){
        df_all = temp
    }
    else{
        df_all = rbind(df_all, temp)
    }
}

# %%
# plot
ggplot(data = df_all,aes(x = bin_abs,y = rt, colour=version)) + 
      geom_point() + 
      #geom_line() +
      geom_errorbar(aes(ymin = rt-rt_se,ymax = rt+rt_se)) + 
      labs(x = "Net Value", y = "Reaction Time (seconds)") +
      theme_minimal() +
      ggtitle("Mean Reaction Time by abs(Net Value)")
# Out:
# plot without title

# %% [markdown]
# ## Fixations
# by Abs. Offer Value

# %% [markdown]
# ### Function

# %%
fix_func = function(df) {
    subjects = length(unique(df$subject))

    fix = df %>%
        group_by(subject, bin_abs) %>%
        summarise(swaps = mean(swapAmount)) %>%
        group_by(bin_abs) %>%
        summarise(N = length(swaps),
                  fix_se = sd(swaps) / sqrt(subjects),
                  fix_num = mean(swaps)
                 ) %>%
        mutate(bin_abs = round(as.numeric(as.character(bin_abs)), 2))

    #head(fix, 3)
    
    ggplot(data = fix,aes(x = bin_abs,y = fix_num)) + 
      geom_point() + 
      #geom_line() +
      geom_errorbar(aes(ymin = fix_num-fix_se,ymax = fix_num+fix_se)) + 
      labs(x = "Net Value", y = "Fixations (count)") +
      theme_minimal() +
      ggtitle("Mean Fixation Count by abs(Net Value)")
    
    #return(fix)
}

# %% [markdown]
# ### V1

# %%
fix_func(v1)
# Out:
# plot without title

# %% [markdown]
# ### V2

# %%
fix_func(v2)
# Out:
# plot without title

# %% [markdown]
# ### V3.0.1

# %%
v301$swapAmount = v301$total_stim_fix
fix_func(v301)
# Out:
# plot without title

# %% [markdown]
# ### V3.0.2

# %%
v302$swapAmount = v302$total_stim_fix
fix_func(v302)
# Out:
# plot without title

# %% [markdown]
# ### V3.1.0

# %% [markdown]
# ### Comparisons

# %%
# clean up
rm(df_all)

# %%
# list of dfs we want tocompare
df.list = list(v1, v2, v301, v302)

# %%
# make df with all versions
for (df in df.list){
    subjects = length(unique(df$subject))
    version = df$version[1]

    temp = df %>%
            group_by(subject, bin_abs) %>%
            summarise(swaps = mean(swapAmount)) %>%
            group_by(bin_abs) %>%
            summarise(N = length(swaps),
                      fix_se = sd(swaps) / sqrt(subjects),
                      fix_num = mean(swaps)
                     ) %>%
            mutate(bin_abs = round(as.numeric(as.character(bin_abs)), 2),
                  version = version)
    
    if(!exists("df_all")){
        df_all = temp
    }
    else{
        df_all = rbind(df_all, temp)
    }
}

# %%
# plot
ggplot(data = df_all,aes(x = bin_abs,y = fix_num, colour=version)) + 
      geom_point() + 
      #geom_line() +
      geom_errorbar(aes(ymin = fix_num-fix_se,ymax = fix_num+fix_se)) + 
      labs(x = "Net Value", y = "Fixations (count)") +
      theme_minimal() +
      ggtitle("Mean Fixation Count by abs(Net Value)")
# Out:
# plot without title

# %% [markdown]
# ## P(Accept)
# by Offer Value

# %% [markdown]
# ### V1

# %%
accept_func = function(df){
    subjects = length(unique(df$subject))

    # p(accept)
    p_a = df %>%
        group_by(subject, bin) %>%
        summarise(accept = mean(choice)) %>%
        group_by(bin) %>%
        summarise(N = length(accept),
                  accept_se = sd(accept, na.rm=TRUE) / sqrt(subjects),
                  accept = mean(accept)
                 ) %>%
        mutate(bin = round(as.numeric(as.character(bin)), 2))

    #head(p_a, 3)
    ggplot(data = p_a,aes(x = bin,y = accept)) + 
      geom_point() + 
      #geom_line() +
      geom_errorbar(aes(ymin = accept-accept_se, ymax = accept+accept_se)) + 
      labs(x = "Net Value", y = "Fixations (count)") +
      theme_minimal() +
      ggtitle("Mean Fixation Count by abs(Net Value)")
    #return(p_a)
}

# %% [markdown]
# ### V1

# %%
accept_func(v1)
# Out:
# plot without title

# %% [markdown]
# ### V2

# %%
accept_func(v2)
# Out:
# Warning message:
# “Removed 3 rows containing missing values (geom_point).”Warning message:
# “Removed 3 rows containing missing values (geom_errorbar).”
# plot without title

# %% [markdown]
# ### V3.0.1

# %%
v301$choice = v301$response
accept_func(v301)
# Out:
# plot without title

# %% [markdown]
# ### V3.0.2

# %%
v302$choice = v302$response
accept_func(v302)
# Out:
# plot without title

# %% [markdown]
# ### V3.1.0

# %% [markdown]
# ### Comparisons

# %%
# clean up
rm(df_all)

# %%
# list of dfs we want tocompare
df.list = list(v1, v2, v301, v302)

# %%
# make df with all versions
for (df in df.list){
    subjects = length(unique(df$subject))
    version = df$version[1]

    temp = df %>%
            group_by(subject, bin) %>%
            summarise(accept = mean(choice)) %>%
            group_by(bin) %>%
            summarise(N = length(accept),
                      accept_se = sd(accept, na.rm=TRUE) / sqrt(subjects),
                      accept = mean(accept)
                     ) %>%
            mutate(bin = round(as.numeric(as.character(bin)), 2),
                  version = version)
    
    if(!exists("df_all")){
        df_all = temp
    }
    else{
        df_all = rbind(df_all, temp)
    }
}

# %%
ggplot(data = df_all, aes(x = bin,y = accept, colour=version)) + 
      geom_point() + 
      #geom_line() +
      geom_errorbar(aes(ymin = accept-accept_se, ymax = accept+accept_se)) + 
      labs(x = "Net Value", y = "Fixations (count)") +
      theme_minimal() +
      ggtitle("Mean Fixation Count by abs(Net Value)")
# Out:
# Warning message:
# “Removed 6 rows containing missing values (geom_point).”Warning message:
# “Removed 6 rows containing missing values (geom_errorbar).”
# plot without title

# %% [markdown]
# # Attention

# %% [markdown]
# ## Base Value

# %% [markdown]
# ### First Fixation

# %%
first_fix_plot = function(df){

    #RT vs. Summed Value
    ggplot() +
      geom_smooth(aes(x=firstVal/firstMult, y=`1_fixation`, group = factor(firstMult), colour = factor(firstMult)), df) +
      #geom_smooth(aes(x=summedVal, y=rt, colour = "flip"), subset(df, flip==1)) +
      coord_cartesian(xlim = c(-1, 1))  +
      #ggtitle("RT vs. Summed Val")
      #geom_point(shape=1) +    # Use hollow circles
      geom_smooth() +  # Add a loess smoothed fit curve with confidence region
      theme_minimal()+
      guides(colour=guide_legend("Multiplier \nCondition")) +
      scale_x_continuous(name="Value ($)", seq(-1,1,0.25), limits = c(-1,1))+
      scale_y_continuous(name = "Reaction Time (s)") +
      ggtitle("Mean Fixation Duration by Base Value and Multiplier")
}

first_fix_plot_abs = function(df){
    ggplot() +
      geom_smooth(aes(x=abs(firstVal/firstMult), y=`1_fixation`, group = factor(firstMult), colour = factor(firstMult)), df) +
      #geom_smooth(aes(x=summedVal, y=rt, colour = "flip"), subset(df, flip==1)) +
      coord_cartesian(xlim = c(0, 1))  +
      #ggtitle("RT vs. Summed Val")
      #geom_point(shape=1) +    # Use hollow circles
      geom_smooth() +  # Add a loess smoothed fit curve with confidence region
      theme_minimal()+
      guides(colour=guide_legend("Multiplier \nCondition")) +
      scale_x_continuous(name="Absolute Value ($)", seq(0,1,0.25), limits = c(0,1))+
      scale_y_continuous(name = "Reaction Time (s)") +
      ggtitle("Mean Fixation Duration by abs(Base Value) and Multiplier")
}

# %% [markdown]
# #### V1

# %%
first_fix_plot(v1)
first_fix_plot_abs(v1)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title
# plot without title

# %%
m.lmer <- lmer (`1_fixation` ~ abs(firstVal/firstMult) * firstMult + (1 + abs(firstVal/firstMult) |subject),
                data = v1)
summary(m.lmer)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# `1_fixation` ~ abs(firstVal/firstMult) * firstMult + (1 + abs(firstVal/firstMult) |
#     subject)
#    Data: v1
#
# REML criterion at convergence: 15013.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.1932 -0.4641 -0.2199  0.1365  9.1406
#
# Random effects:
#  Groups   Name                    Variance Std.Dev. Corr
#  subject  (Intercept)             0.26210  0.5120
#           abs(firstVal/firstMult) 0.08274  0.2876   -0.99
#  Residual                         0.56006  0.7484
# Number of obs: 6597, groups:  subject, 23
#
# Fixed effects:
#                                     Estimate Std. Error         df t value
# (Intercept)                          0.91129    0.11589   28.01278   7.864
# abs(firstVal/firstMult)             -0.12506    0.09829   79.71755  -1.272
# firstMult                            0.06782    0.02496 6569.82113   2.717
# abs(firstVal/firstMult):firstMult   -0.05683    0.04567 6549.78596  -1.244
#                                   Pr(>|t|)
# (Intercept)                       1.44e-08 ***
# abs(firstVal/firstMult)            0.20697
# firstMult                          0.00661 **
# abs(firstVal/firstMult):firstMult  0.21341
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) ab(V/M) frstMl
# abs(frsV/M) -0.829
# firstMult   -0.346  0.643
# abs(fV/M):M  0.297 -0.705  -0.886

# %% [markdown]
# #### V2

# %%
first_fix_plot(v2)
first_fix_plot_abs(v2)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title
# plot without title

# %%
#Test for SIG
m.lmer <- lmer (`1_fixation` ~ abs(firstVal/firstMult) * firstMult + (1 + abs(firstVal/firstMult) |subject), 
                data = v2)
summary(m.lmer)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# `1_fixation` ~ abs(firstVal/firstMult) * firstMult + (1 + abs(firstVal/firstMult) |
#     subject)
#    Data: v2
#
# REML criterion at convergence: 34451.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8277 -0.4863 -0.2543  0.1236  8.8377
#
# Random effects:
#  Groups   Name                    Variance Std.Dev. Corr
#  subject  (Intercept)             0.2769   0.5262
#           abs(firstVal/firstMult) 0.1727   0.4155   -0.86
#  Residual                         1.1028   1.0502
# Number of obs: 11674, groups:  subject, 31
#
# Fixed effects:
#                                     Estimate Std. Error         df t value
# (Intercept)                        1.243e+00  9.765e-02  3.150e+01  12.729
# abs(firstVal/firstMult)           -2.663e-01  8.571e-02  3.626e+01  -3.107
# firstMult                          1.064e-02  6.526e-03  1.162e+04   1.630
# abs(firstVal/firstMult):firstMult  1.770e-03  1.097e-02  1.163e+04   0.161
#                                   Pr(>|t|)
# (Intercept)                       5.86e-14 ***
# abs(firstVal/firstMult)            0.00366 **
# firstMult                          0.10314
# abs(firstVal/firstMult):firstMult  0.87182
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) ab(V/M) frstMl
# abs(frsV/M) -0.835
# firstMult   -0.152  0.255
# abs(fV/M):M  0.133 -0.299  -0.868

# %% [markdown]
# #### V3.0.1

# %%
first_fix_plot = function(df_long){
    # get first fix val and mult
    df = df_long %>%
        filter(which_fix == 1) %>%
        select(subject, trial, fix_rt, fix_stim_val_base, fix_stim_mult)
    
    #RT vs. Summed Value
    ggplot() +
      geom_smooth(aes(x=fix_stim_val_base, y=fix_rt, 
                      group = factor(fix_stim_mult), 
                      colour = factor(fix_stim_mult)), df) +
      coord_cartesian(xlim = c(-1, 1))  +
      geom_smooth() +  # Add a loess smoothed fit curve with confidence region
      theme_minimal()+
      guides(colour=guide_legend("Multiplier \nCondition")) +
      scale_x_continuous(name="Base Value ($)", seq(-1,1,0.25), limits = c(-1,1))+
      scale_y_continuous(name = "Reaction Time (s)") +
      ggtitle("Mean Fixation Duration by Base Value and Multiplier")
}

first_fix_plot_abs = function(df_long){
    # get first fix val and mult
    df = df_long %>%
        filter(which_fix == 1) %>%
        select(subject, trial, fix_rt, fix_stim_val_base, fix_stim_mult)
    
    #RT vs. Summed Value
    ggplot() +
      geom_smooth(aes(x=abs(fix_stim_val_base), y=fix_rt, 
                      group = factor(fix_stim_mult), 
                      colour = factor(fix_stim_mult)), df) +
      coord_cartesian(xlim = c(0, 1))  +
      geom_smooth() +  # Add a loess smoothed fit curve with confidence region
      theme_minimal()+
      guides(colour=guide_legend("Multiplier \nCondition")) +
      scale_x_continuous(name="Absolute Base Value ($)", seq(0,1,0.25), limits = c(0,1))+
      scale_y_continuous(name = "Reaction Time (s)") +
      ggtitle("Mean Fixation Duration by abs(Base Value) and Multiplier")
}

# %%
first_fix_plot(v301_long)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
first_fix_plot_abs(v301_long)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
x = v301_long %>%
        filter(which_fix == 1) %>%
        select(subject, trial, fix_rt, fix_stim_val_base, fix_stim_mult)

# %%
#Test for SIG
m.lmer <- lmer (fix_rt ~ abs(fix_stim_val_base) * fix_stim_mult + (1 |subject), data = x)
summary(m.lmer)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: fix_rt ~ abs(fix_stim_val_base) * fix_stim_mult + (1 | subject)
#    Data: x
#
# REML criterion at convergence: 20797.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.3048 -0.4494 -0.1515  0.1769 14.2943
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.4209   0.6488
#  Residual             1.1709   1.0821
# Number of obs: 6901, groups:  subject, 23
#
# Fixed effects:
#                                        Estimate Std. Error         df t value
# (Intercept)                           1.579e+00  1.391e-01  2.404e+01  11.356
# abs(fix_stim_val_base)               -4.693e-01  5.486e-02  6.875e+03  -8.555
# fix_stim_mult                         1.195e-02  9.306e-03  6.875e+03   1.284
# abs(fix_stim_val_base):fix_stim_mult -5.403e-03  1.614e-02  6.875e+03  -0.335
#                                      Pr(>|t|)
# (Intercept)                           3.8e-11 ***
# abs(fix_stim_val_base)                < 2e-16 ***
# fix_stim_mult                           0.199
# abs(fix_stim_val_base):fix_stim_mult    0.738
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) ab(___) fx_st_
# abs(fx_s__) -0.199
# fix_stm_mlt -0.134  0.504
# abs(___):__  0.115 -0.583  -0.855

# %% [markdown]
# #### V3.0.2

# %%
first_fix_plot(v302_long)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
first_fix_plot_abs(v302_long)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
x = v302_long %>%
        filter(which_fix == 1) %>%
        select(subject, trial, fix_rt, fix_stim_val_base, fix_stim_mult)

# %%
#Test for SIG
m.lmer <- lmer (fix_rt ~ abs(fix_stim_val_base) * fix_stim_mult + (1 |subject), data = x)
summary(m.lmer)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: fix_rt ~ abs(fix_stim_val_base) * fix_stim_mult + (1 | subject)
#    Data: x
#
# REML criterion at convergence: 20797.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.3048 -0.4494 -0.1515  0.1769 14.2943
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.4209   0.6488
#  Residual             1.1709   1.0821
# Number of obs: 6901, groups:  subject, 23
#
# Fixed effects:
#                                        Estimate Std. Error         df t value
# (Intercept)                           1.579e+00  1.391e-01  2.404e+01  11.356
# abs(fix_stim_val_base)               -4.693e-01  5.486e-02  6.875e+03  -8.555
# fix_stim_mult                         1.195e-02  9.306e-03  6.875e+03   1.284
# abs(fix_stim_val_base):fix_stim_mult -5.403e-03  1.614e-02  6.875e+03  -0.335
#                                      Pr(>|t|)
# (Intercept)                           3.8e-11 ***
# abs(fix_stim_val_base)                < 2e-16 ***
# fix_stim_mult                           0.199
# abs(fix_stim_val_base):fix_stim_mult    0.738
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) ab(___) fx_st_
# abs(fx_s__) -0.199
# fix_stm_mlt -0.134  0.504
# abs(___):__  0.115 -0.583  -0.855

# %% [markdown]
# #### V3.1.0

# %% [markdown]
# #### Comparisons

# %% [markdown]
# ### Middle (2nd) Fixation

# %%
second_fix_plot = function(df){

    #RT vs. Summed Value
    ggplot() +
      geom_smooth(aes(x=secondVal/secondMult, y=`2_fixation`, group = factor(secondMult), colour = factor(secondMult)), df) +
      coord_cartesian(xlim = c(-1, 1))  +
      geom_smooth() +  # Add a loess smoothed fit curve with confidence region
      theme_minimal()+
      guides(colour=guide_legend("Multiplier \nCondition")) +
      scale_x_continuous(name="Value ($)", seq(-1,1,0.25), limits = c(-1,1))+
      scale_y_continuous(name = "Reaction Time (s)") +
      ggtitle("Mean Fixation Duration by Base Value and Multiplier")
}

second_fix_plot_abs = function(df){
    ggplot() +
      geom_smooth(aes(x=abs(secondVal/secondMult), y=`2_fixation`, group = factor(secondMult), colour = factor(secondMult)), df) +
      #geom_smooth(aes(x=summedVal, y=rt, colour = "flip"), subset(df, flip==1)) +
      coord_cartesian(xlim = c(0, 1))  +
      #ggtitle("RT vs. Summed Val")
      #geom_point(shape=1) +    # Use hollow circles
      geom_smooth() +  # Add a loess smoothed fit curve with confidence region
      theme_minimal()+
      guides(colour=guide_legend("Multiplier \nCondition")) +
      scale_x_continuous(name="Absolute Value ($)", seq(0,1,0.25), limits = c(0,1))+
      scale_y_continuous(name = "Reaction Time (s)") +
      ggtitle("Mean Fixation Duration by abs(Base Value) and Multiplier")
}

# %% [markdown]
# #### V1

# %%
second_fix_plot(v1)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# Warning message:
# “Removed 17 rows containing non-finite values (stat_smooth).”
# plot without title

# %%
second_fix_plot_abs(v1)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# Warning message:
# “Removed 17 rows containing non-finite values (stat_smooth).”
# plot without title

# %%
#Test for SIG
m.lmer <- lmer (`2_fixation` ~ abs(secondVal/secondMult) * secondMult + (1 + abs(secondVal/secondMult) |subject), 
                data = v1)
summary(m.lmer)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: `2_fixation` ~ abs(secondVal/secondMult) * secondMult + (1 +
#     abs(secondVal/secondMult) | subject)
#    Data: v1
#
# REML criterion at convergence: 10988.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2984 -0.5209 -0.1952  0.2644 12.1090
#
# Random effects:
#  Groups   Name                      Variance Std.Dev. Corr
#  subject  (Intercept)               0.12125  0.3482
#           abs(secondVal/secondMult) 0.04177  0.2044   -0.77
#  Residual                           0.30455  0.5519
# Number of obs: 6580, groups:  subject, 23
#
# Fixed effects:
#                                        Estimate Std. Error         df t value
# (Intercept)                             0.99437    0.07987   29.19051  12.450
# abs(secondVal/secondMult)              -0.01038    0.07143   87.65095  -0.145
# secondMult                              0.14920    0.01845 6548.73256   8.085
# abs(secondVal/secondMult):secondMult   -0.14382    0.03399 6549.80226  -4.231
#                                      Pr(>|t|)
# (Intercept)                          3.34e-13 ***
# abs(secondVal/secondMult)               0.885
# secondMult                           7.35e-16 ***
# abs(secondVal/secondMult):secondMult 2.35e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) ab(V/M) scndMl
# abs(scnV/M) -0.715
# secondMult  -0.370  0.654
# abs(sV/M):M  0.317 -0.715  -0.886

# %% [markdown]
# #### V2

# %%
second_fix_plot(v2)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
second_fix_plot_abs(v2)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
#Test for SIG
m.lmer <- lmer (`2_fixation` ~ abs(secondVal/secondMult) * secondMult + (1 + abs(secondVal/secondMult) |subject), 
                data = v2)
summary(m.lmer)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: `2_fixation` ~ abs(secondVal/secondMult) * secondMult + (1 +
#     abs(secondVal/secondMult) | subject)
#    Data: v2
#
# REML criterion at convergence: 23136.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.3300 -0.5166 -0.2189  0.2466 13.3749
#
# Random effects:
#  Groups   Name                      Variance Std.Dev. Corr
#  subject  (Intercept)               0.12358  0.3515
#           abs(secondVal/secondMult) 0.05309  0.2304   -0.86
#  Residual                           0.41816  0.6467
# Number of obs: 11674, groups:  subject, 31
#
# Fixed effects:
#                                        Estimate Std. Error         df t value
# (Intercept)                           1.229e+00  6.496e-02  3.124e+01  18.916
# abs(secondVal/secondMult)            -2.068e-01  4.885e-02  3.754e+01  -4.232
# secondMult                            2.600e-02  4.141e-03  1.163e+04   6.278
# abs(secondVal/secondMult):secondMult -2.253e-02  7.083e-03  1.163e+04  -3.181
#                                      Pr(>|t|)
# (Intercept)                           < 2e-16 ***
# abs(secondVal/secondMult)            0.000143 ***
# secondMult                           3.54e-10 ***
# abs(secondVal/secondMult):secondMult 0.001473 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) ab(V/M) scndMl
# abs(scnV/M) -0.816
# secondMult  -0.142  0.281
# abs(sV/M):M  0.123 -0.322  -0.870

# %% [markdown]
# #### V3.0.1

# %%
mid_fix_plot = function(df_long){
    # get first fix val and mult
    df = df_long %>%
        filter(which_fix == 2) %>%
        select(subject, trial, fix_rt, fix_stim_val_base, fix_stim_mult)
    
    #RT vs. Summed Value
    ggplot() +
      geom_smooth(aes(x=fix_stim_val_base, y=fix_rt, 
                      group = factor(fix_stim_mult), 
                      colour = factor(fix_stim_mult)), df) +
      coord_cartesian(xlim = c(-1, 1))  +
      geom_smooth() +  # Add a loess smoothed fit curve with confidence region
      theme_minimal()+
      guides(colour=guide_legend("Multiplier \nCondition")) +
      scale_x_continuous(name="Base Value ($)", seq(-1,1,0.25), limits = c(-1,1))+
      scale_y_continuous(name = "Reaction Time (s)") +
      ggtitle("Mean Fixation Duration by Base Value and Multiplier")
}

mid_fix_plot_abs = function(df_long){
    # get first fix val and mult
    df = df_long %>%
        filter(which_fix == 2) %>%
        select(subject, trial, fix_rt, fix_stim_val_base, fix_stim_mult)
    
    #RT vs. Summed Value
    ggplot() +
      geom_smooth(aes(x=abs(fix_stim_val_base), y=fix_rt, 
                      group = factor(fix_stim_mult), 
                      colour = factor(fix_stim_mult)), df) +
      coord_cartesian(xlim = c(0, 1))  +
      geom_smooth() +  # Add a loess smoothed fit curve with confidence region
      theme_minimal()+
      guides(colour=guide_legend("Multiplier \nCondition")) +
      scale_x_continuous(name="Absolute Base Value ($)", seq(0,1,0.25), limits = c(0,1))+
      scale_y_continuous(name = "Reaction Time (s)") +
      ggtitle("Mean Fixation Duration by abs(Base Value) and Multiplier")
}

# %%
mid_fix_plot(v301_long)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
mid_fix_plot_abs(v301_long)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
x = v301_long %>%
        filter(which_fix == 2) %>%
        select(subject, trial, fix_rt, fix_stim_val_base, fix_stim_mult)

# %%
#Test for SIG
m.lmer <- lmer (fix_rt ~ abs(fix_stim_val_base) * fix_stim_mult + (1 |subject), data = x)
summary(m.lmer)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: fix_rt ~ abs(fix_stim_val_base) * fix_stim_mult + (1 | subject)
#    Data: x
#
# REML criterion at convergence: 10611.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.3370 -0.4761 -0.1733  0.2196 11.3947
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.1967   0.4436
#  Residual             0.7645   0.8744
# Number of obs: 4099, groups:  subject, 15
#
# Fixed effects:
#                                        Estimate Std. Error         df t value
# (Intercept)                           1.053e+00  1.196e-01  1.597e+01   8.797
# abs(fix_stim_val_base)               -1.191e-01  5.841e-02  4.082e+03  -2.039
# fix_stim_mult                         2.182e-02  9.947e-03  4.082e+03   2.194
# abs(fix_stim_val_base):fix_stim_mult -2.481e-02  1.827e-02  4.082e+03  -1.358
#                                      Pr(>|t|)
# (Intercept)                          1.61e-07 ***
# abs(fix_stim_val_base)                 0.0415 *
# fix_stim_mult                          0.0283 *
# abs(fix_stim_val_base):fix_stim_mult   0.1746
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) ab(___) fx_st_
# abs(fx_s__) -0.241
# fix_stm_mlt -0.160  0.502
# abs(___):__  0.134 -0.571  -0.850

# %% [markdown]
# #### V3.0.2

# %%
mid_fix_plot(v302_long)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
mid_fix_plot_abs(v302_long)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
x = v302_long %>%
        filter(which_fix == 2) %>%
        select(subject, trial, fix_rt, fix_stim_val_base, fix_stim_mult)

# %%
#Test for SIG
m.lmer <- lmer (fix_rt ~ abs(fix_stim_val_base) * fix_stim_mult + (1 |subject), data = x)
summary(m.lmer)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: fix_rt ~ abs(fix_stim_val_base) * fix_stim_mult + (1 | subject)
#    Data: x
#
# REML criterion at convergence: 18822.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7790 -0.4903 -0.1858  0.2135 11.6460
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.1925   0.4387
#  Residual             0.7041   0.8391
# Number of obs: 7521, groups:  subject, 23
#
# Fixed effects:
#                                        Estimate Std. Error         df t value
# (Intercept)                           1.218e+00  9.481e-02  2.415e+01  12.847
# abs(fix_stim_val_base)               -9.821e-02  4.097e-02  7.497e+03  -2.397
# fix_stim_mult                         2.109e-02  7.259e-03  7.496e+03   2.905
# abs(fix_stim_val_base):fix_stim_mult -3.990e-02  1.403e-02  7.495e+03  -2.845
#                                      Pr(>|t|)
# (Intercept)                          2.74e-12 ***
# abs(fix_stim_val_base)                0.01654 *
# fix_stim_mult                         0.00368 **
# abs(fix_stim_val_base):fix_stim_mult  0.00446 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) ab(___) fx_st_
# abs(fx_s__) -0.206
# fix_stm_mlt -0.136  0.496
# abs(___):__  0.111 -0.570  -0.826

# %% [markdown]
# #### V3.1.0

# %% [markdown]
# #### Comparisons

# %% [markdown]
# ### Final Fixation

# %% [markdown]
# #### V1

# %% [markdown]
# #### V2

# %% [markdown]
# #### V3.0.1

# %%
final_fix_plot = function(df_long){
    # get first fix val and mult
    df = df_long %>%
        filter(which_fix == 3) %>%
        select(subject, trial, fix_rt, fix_stim_val_base, fix_stim_mult)
    
    #RT vs. Summed Value
    ggplot() +
      geom_smooth(aes(x=fix_stim_val_base, y=fix_rt, 
                      group = factor(fix_stim_mult), 
                      colour = factor(fix_stim_mult)), df) +
      coord_cartesian(xlim = c(-1, 1))  +
      geom_smooth() +  # Add a loess smoothed fit curve with confidence region
      theme_minimal()+
      guides(colour=guide_legend("Multiplier \nCondition")) +
      scale_x_continuous(name="Base Value ($)", seq(-1,1,0.25), limits = c(-1,1))+
      scale_y_continuous(name = "Reaction Time (s)") +
      ggtitle("Mean Fixation Duration by Base Value and Multiplier")
}

final_fix_plot_abs = function(df_long){
    # get first fix val and mult
    df = df_long %>%
        filter(which_fix == 3) %>%
        select(subject, trial, fix_rt, fix_stim_val_base, fix_stim_mult)
    
    #RT vs. Summed Value
    ggplot() +
      geom_smooth(aes(x=abs(fix_stim_val_base), y=fix_rt, 
                      group = factor(fix_stim_mult), 
                      colour = factor(fix_stim_mult)), df) +
      coord_cartesian(xlim = c(0, 1))  +
      geom_smooth() +  # Add a loess smoothed fit curve with confidence region
      theme_minimal()+
      guides(colour=guide_legend("Multiplier \nCondition")) +
      scale_x_continuous(name="Absolute Base Value ($)", seq(0,1,0.25), limits = c(0,1))+
      scale_y_continuous(name = "Reaction Time (s)") +
      ggtitle("Mean Fixation Duration by abs(Base Value) and Multiplier")
}

# %%
final_fix_plot(v301_long)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
final_fix_plot_abs(v301_long)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
x = v301_long %>%
        filter(which_fix == 3) %>%
        select(subject, trial, fix_rt, fix_stim_val_base, fix_stim_mult)

# %%
#Test for SIG
m.lmer <- lmer (fix_rt ~ abs(fix_stim_val_base) * fix_stim_mult + (1 |subject), data = x)
summary(m.lmer)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: fix_rt ~ abs(fix_stim_val_base) * fix_stim_mult + (1 | subject)
#    Data: x
#
# REML criterion at convergence: 10620.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.3412 -0.5295 -0.1530  0.2721 13.1175
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.0728   0.2698
#  Residual             0.3622   0.6018
# Number of obs: 5780, groups:  subject, 15
#
# Fixed effects:
#                                        Estimate Std. Error         df t value
# (Intercept)                           8.150e-01  7.236e-02  1.589e+01  11.262
# abs(fix_stim_val_base)               -6.460e-02  3.368e-02  5.762e+03  -1.918
# fix_stim_mult                         3.255e-02  5.520e-03  5.762e+03   5.897
# abs(fix_stim_val_base):fix_stim_mult -3.735e-02  9.361e-03  5.762e+03  -3.990
#                                      Pr(>|t|)
# (Intercept)                          5.54e-09 ***
# abs(fix_stim_val_base)                 0.0552 .
# fix_stim_mult                        3.91e-09 ***
# abs(fix_stim_val_base):fix_stim_mult 6.69e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) ab(___) fx_st_
# abs(fx_s__) -0.234
# fix_stm_mlt -0.160  0.507
# abs(___):__  0.139 -0.590  -0.866

# %% [markdown]
# #### V3.0.2

# %%
final_fix_plot(v302_long)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
final_fix_plot_abs(v302_long)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
x = v302_long %>%
        filter(which_fix == 3) %>%
        select(subject, trial, fix_rt, fix_stim_val_base, fix_stim_mult)

# %%
#Test for SIG
m.lmer <- lmer (fix_rt ~ abs(fix_stim_val_base) * fix_stim_mult + (1 |subject), data = x)
summary(m.lmer)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: fix_rt ~ abs(fix_stim_val_base) * fix_stim_mult + (1 | subject)
#    Data: x
#
# REML criterion at convergence: 17891.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4471 -0.5299 -0.1584  0.2310 12.6746
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.1589   0.3986
#  Residual             0.7066   0.8406
# Number of obs: 7136, groups:  subject, 23
#
# Fixed effects:
#                                        Estimate Std. Error         df t value
# (Intercept)                           1.090e+00  8.692e-02  2.550e+01  12.536
# abs(fix_stim_val_base)               -2.042e-01  4.307e-02  7.111e+03  -4.740
# fix_stim_mult                         3.814e-02  6.424e-03  7.111e+03   5.938
# abs(fix_stim_val_base):fix_stim_mult -3.983e-02  1.100e-02  7.111e+03  -3.622
#                                      Pr(>|t|)
# (Intercept)                          2.10e-12 ***
# abs(fix_stim_val_base)               2.18e-06 ***
# fix_stim_mult                        3.03e-09 ***
# abs(fix_stim_val_base):fix_stim_mult 0.000295 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) ab(___) fx_st_
# abs(fx_s__) -0.253
# fix_stm_mlt -0.177  0.530
# abs(___):__  0.153 -0.610  -0.863

# %% [markdown]
# #### V3.1.0

# %% [markdown]
# #### Comparisons

# %% [markdown]
# ## Multiplier

# %% [markdown]
# ### First Fixation

# %% [markdown]
# #### V1

# %% [markdown]
# #### V2

# %% [markdown]
# #### V3.0.1

# %% [markdown]
# #### V3.0.2

# %% [markdown]
# #### V3.1.0

# %% [markdown]
# #### Comparisons

# %% [markdown]
# ### Middle Fixation

# %% [markdown]
# #### V1

# %% [markdown]
# #### V2

# %% [markdown]
# #### V3.0.1

# %% [markdown]
# #### V3.0.2

# %% [markdown]
# #### V3.1.0

# %% [markdown]
# #### Comparisons

# %% [markdown]
# ### Final Fixation

# %% [markdown]
# #### V1

# %% [markdown]
# #### V2

# %% [markdown]
# #### V3.0.1

# %% [markdown]
# #### V3.0.2

# %% [markdown]
# #### V3.1.0

# %% [markdown]
# #### Comparisons

# %% [markdown]
# ## Weighted Value

# %% [markdown]
# ### First Fixation

# %% [markdown]
# #### V1

# %% [markdown]
# #### V2

# %% [markdown]
# #### V3.0.1

# %% [markdown]
# #### V3.0.2

# %% [markdown]
# #### V3.1.0

# %% [markdown]
# #### Comparisons

# %% [markdown]
# ### Middle Fixation

# %% [markdown]
# #### V1

# %% [markdown]
# #### V2

# %% [markdown]
# #### V3.0.1

# %% [markdown]
# #### V3.0.2

# %% [markdown]
# #### V3.1.0

# %% [markdown]
# #### Comparisons

# %% [markdown]
# ### Final Fixation

# %% [markdown]
# #### V1

# %% [markdown]
# #### V2

# %% [markdown]
# #### V3.0.1

# %% [markdown]
# #### V3.0.2

# %% [markdown]
# #### V3.1.0

# %% [markdown]
# #### Comparisons

# %% [markdown]
# # Choice ~ Attention & Value
