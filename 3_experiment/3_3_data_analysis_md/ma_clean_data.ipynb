# %% [markdown]
# # Imports
# ---

# %%
library(tidyverse)
library(boot)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# # Versions

# %% [markdown]
# ## v1

# %% [markdown]
# ## v2

# %% [markdown]
# ---
# ## v3.0.1
# ---

# %% [markdown]
# ### Import Data
# ---

# %%
# Clean up: Remove all vars
rm(list = setdiff(ls(), lsf.str()))

# %%
# Subjects who completed
subs = c(1,11,14,15,17,20,21,24,26, 27, 28, 29, 30, 31, 35, 37, 40,
        77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 93, 94)

# Dropbox path
dropbox = "/Users/djw/Dropbox/DJW_Projects/01_MADE/CODE/v3/subject_data"

# iterate through subject data, save to single dataFrame
for(sub in subs){
    temp = read_csv(Sys.glob(file.path(dropbox, as.character(sub), "*trials*")))
    
    if(!exists("df_v301")){
        df_v301 = temp
    }
    else{
        df_v301 = rbind(df_v301, temp)
    }
}
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.

# %% [markdown]
# ---
# ## v3.0.2
# ---

# %% [markdown]
# ### Import Data
# ---

# %%
# Clean up: Remove all vars
rm(list = setdiff(ls(), lsf.str()))

# %%
# Subjects who completed
subs = c(41, 42, 49, 50, 51, 56, 57, 63, 69, 70, 71, 73, 74, 43, 44, 47, 53, 58, 59, 61, 62, 64, 65, 67, 72, 75)

# Dropbox path
dropbox = "/Users/djw/Dropbox/DJW_Projects/01_MADE/CODE/v3/subject_data"

# iterate through subject data, save to single dataFrame
for(sub in subs){
    temp = read_csv(Sys.glob(file.path(dropbox, as.character(sub), "*trials*")))
    
    if(!exists("df_v302")){
        df_v302 = temp
    }
    else{
        df_v302 = rbind(df_v302, temp)
    }
}
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.

# %%
# number of subjects
length(unique(df_v302$subject))
# Out:
# [1] 26

# %% [markdown]
# ---
# ## v3.1.0
# ---

# %% [markdown]
# ### Import Data
# ---

# %%
# Clean up: Remove all vars
rm(list = setdiff(ls(), lsf.str()))

# %%
# Subjects who completed
subs = c(95, 96, 97, 98, 100, 103, 104, 105, 106, 107, 109, 111, 114, 115, 117, 119, 120, 121, 122,
        125, 126, 131, 132, 136, 137, 142, 145, 146, 147, 151, 152)

# Dropbox path
dropbox = "/Users/djw/Dropbox/DJW_Projects/01_MADE/CODE/v3/subject_data"

# no tp df
# iterate through subject data, save to single dataFrame
for(sub in subs){
    temp = read_csv(Sys.glob(file.path(dropbox, as.character(sub), "*trials_2*")))
    
    if(!exists("df_v310_notp")){
        df_v310_notp = temp
    }
    else{
        df_v310_notp = rbind(df_v310_notp, temp)
    }
}

# tp df
# iterate through subject data, save to single dataFrame
for(sub in subs){
    temp = read_csv(Sys.glob(file.path(dropbox, as.character(sub), "*trials_tp*")))
    
    if(!exists("df_v310_tp")){
        df_v310_tp = temp
    }
    else{
        df_v310_tp = rbind(df_v310_tp, temp)
    }
}
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.

# %%
# how many subjects
length(unique(df_v310_tp$subject))
# Out:
# [1] 31

# %%
df_v310_notp$condition = 'no_tp'
df_v310_tp$condition = 'tp'

# %%
df_v310_notp$tp_rt = NA

# %%
df_v310 = rbind(df_v310_notp, df_v310_tp)

# %%
df_v310 %>%
    group_by(condition) %>%
    summarise(mean_rt = mean(rt),
             median_rt = median(rt),
             sd_rt = sd(rt))
# Out:
#   condition mean_rt  median_rt sd_rt
# 1 no_tp     8.045045 5.966     6.985395
# 2 tp        2.803318 2.583     1.158952

# %% [markdown]
# ---
# ## v3.1.1
# ---
#
# no/high/low time pressure version

# %% [markdown]
# ### Import Data
# ---

# %%
# Clean up: Remove all vars
rm(list = setdiff(ls(), lsf.str()))

# %%
# Subjects who completed
subs = c(153, 154, 156, 159, 160, 161, 162, 163, 164, 165, 166, 167,
        168, 169, 171, 173, 174, 176, 177, 178, 179, 180, 181, 182,
        183, 184, 185, 186, 187, 188, 189, 190, 192, 195, 197, 199)

# Dropbox path
dropbox = "/Users/djw/Dropbox/DJW_Projects/01_MADE/CODE/v3/subject_data"

# iterate through subject data, save to single dataFrame
for(sub in subs){
    temp = read_csv(Sys.glob(file.path(dropbox, as.character(sub), "*trials_tp*")))
    
    if(!exists("df_v311")){
        df_v311 = temp
    }
    else{
        df_v311 = rbind(df_v311, temp)
    }
}
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   condition = col_character(),
#   face_image = col_character(),
#   house_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.

# %%
# how many subjects
length(unique(df_v311$subject))
# Out:
# [1] 36

# %%
df_v311 %>%
    group_by(condition) %>%
    summarise(mean_rt = mean(rt),
             median_rt = median(rt),
             sd_rt = sd(rt))
# Out:
#   condition          mean_rt  median_rt sd_rt
# 1 High Time Pressure 2.739199 2.367     1.515885
# 2 Low Time Pressure  3.117219 2.583     5.788355
# 3 No Time Pressure   4.101879 3.300     2.900112

# %% [markdown]
# ---
# ## v3.3.0
# ---

# %% [markdown]
# ### Import Data
# ---

# %%
# Clean up: Remove all vars
rm(list = setdiff(ls(), lsf.str()))

# %%
# Accepted subjects
subs = c(201, 202, 203, 206, 207, 208, 209, 210, 213, 216, 217, 218, 219, 220, 221, 222,
        224, 225, 226, 230, 231, 232, 233, 234, 236, 237, 246, 248, 249)

# Dropbox path
dropbox = "/Users/djw/Dropbox/DJW_Projects/01_MADE/CODE/v3/subject_data"

# iterate through subject data, save to single dataFrame
for(sub in subs){
    print(sub)
    # Get Trial
    temp = read_csv(Sys.glob(file.path(dropbox, as.character(sub), "*trials*")))

    if(!exists("df_v330")){
        df_v330 = temp
    }
    else{
        df_v330 = rbind(df_v330, temp)
    }

    # Get their post rating
    temp = read_csv(Sys.glob(file.path(dropbox, as.character(sub), "*rating*")))

    if(!exists("df_v330_rating")){
        df_v330_rating = temp
    }
    else{
        df_v330_rating = rbind(df_v330_rating, temp)
    }

    # Get their recall accuracy
    temp = read_csv(Sys.glob(file.path(dropbox, as.character(sub), "*recall*")))

    if(!exists("df_v330_recall")){
        df_v330_recall = temp
    }
    else{
        df_v330_recall = rbind(df_v330_recall, temp)
    }
}
# Out:
# [1] 201
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 202
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 203
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 206
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 207
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 208
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 209
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 210
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 213
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 216
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 217
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 218
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 219
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 220
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 221
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 222
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 224
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 225
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 226
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 230
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 231
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 232
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 233
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 234
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 236
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 237
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 246
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 248
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )
# [1] 249
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   left = col_character(),
#   unattractive_face_image = col_character(),
#   attractive_face_image = col_character(),
#   fix_stim = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   image = col_character(),
#   image_val = col_double(),
#   own_rating = col_double(),
#   other_rating = col_double(),
#   familiarity = col_double()
# )
# Parsed with column specification:
# cols(
#   date = col_character(),
#   psychopy_version = col_character(),
#   exp_version = col_character(),
#   unattractive_face_version = col_double(),
#   attractive_face_version = col_double(),
#   subject = col_double(),
#   block = col_double(),
#   trial = col_double(),
#   image = col_character(),
#   actual_val = col_double(),
#   input_val = col_double(),
#   rt = col_double(),
#   error = col_double(),
#   total_error = col_double(),
#   accuracy = col_double(),
#   min_accuracy = col_double()
# )

# %%
# number of subjects
length(unique(df_v330$subject))
# Out:
# [1] 29

# %% [markdown]
# ---
# # Add Columns

# %% [markdown]
# ---
# Versions:
#
# `df_v301`: Cumulative reward, Multipliers: [0.1, 0.33, 0.5, 1, 2, 3, 10]
#
# `df_v302`: Accuracy past stratified reward, Multipliers: [0.1, 0.33, 0.5, 1, 2, 3, 10]
#
# `df_v310`: Time Pressure condition, Multipliers: [0.1, 0.33, 0.5, 1, 2, 3, 10]
#
# `df_v311`: Time Pressure condition, Multipliers: [0.1, 0.33, 0.5, 1, 2, 3, 10]
#
# `df_v330`: Time Pressure condition, Multipliers: [0.1, 0.5, 1, 2, 3, 10]
#
# ---

# %%
df = df_v330

# %%
head(df)
# Out:
#   date             psychopy_version exp_version unattractive_face_version
# 1 2019_Jul_04_1013 3.0.2            3.3.0       0
# 2 2019_Jul_04_1013 3.0.2            3.3.0       0
# 3 2019_Jul_04_1013 3.0.2            3.3.0       0
# 4 2019_Jul_04_1013 3.0.2            3.3.0       0
# 5 2019_Jul_04_1013 3.0.2            3.3.0       0
# 6 2019_Jul_04_1013 3.0.2            3.3.0       0
#   attractive_face_version left         subject block trial rt     ⋯
# 1 1                       unattractive 201     0     0     10.767 ⋯
# 2 1                       unattractive 201     0     0     10.767 ⋯
# 3 1                       unattractive 201     0     0     10.767 ⋯
# 4 1                       unattractive 201     0     0     10.767 ⋯
# 5 1                       unattractive 201     0     0     10.767 ⋯
# 6 1                       unattractive 201     0     0     10.767 ⋯
#   attractive_face_image attractive_face_val_base attractive_face_mult
# 1 face_m_a_4_087.jpg    -0.74                    0.5
# 2 face_m_a_4_087.jpg    -0.74                    0.5
# 3 face_m_a_4_087.jpg    -0.74                    0.5
# 4 face_m_a_4_087.jpg    -0.74                    0.5
# 5 face_m_a_4_087.jpg    -0.74                    0.5
# 6 face_m_a_4_087.jpg    -0.74                    0.5
#   attractive_face_val_total fix_num fix_rt fix_stim fix_num_total accuracy
# 1 -0.37                     0       2.267  weights  15            1
# 2 -0.37                     1       1.800  left     15            1
# 3 -0.37                     2       0.050  weights  15            1
# 4 -0.37                     3       0.783  right    15            1
# 5 -0.37                     4       0.000  weights  15            1
# 6 -0.37                     5       0.717  left     15            1
#   payout
# 1 50
# 2 50
# 3 50
# 4 50
# 5 50
# 6 50

# %% [markdown]
# ### Add Total Fixations Column

# %%
# get total fixations for each trial
df = df %>% 
    group_by(subject, trial) %>%
    mutate(total_fix_num = length(fix_num),
          total_weights_fix = sum(fix_stim == "weights"),
          total_stim_fix = sum((fix_stim == "left") | (fix_stim == "right"))
                                 )

# %% [markdown]
# ### Add Which Fixation Column

# %%
df$which_fix = 0

# go through each row and determine which "type" of fixation (must be a better way...)
for (i in seq(dim(df)[1])) {
    
    # for weights fixations code = 0
    if (df$fix_stim[i] == "weights"){
        df$which_fix[i] = 0
    }
    # for last fixation code = 3
    else if((df$fix_num[i]==df$total_fix_num[i]-1) & (df$fix_stim[i] != "weights")){
        df$which_fix[i] = 3
    }
    else if((df$fix_num[i]==df$total_fix_num[i]-2) & (df$fix_stim[i] != "weights")){
        df$which_fix[i] = 3
    }
    # for first fixation code = 1
    else if((df$fix_num[i]==0) & (df$fix_stim[i] != "weights")){
        df$which_fix[i] = 1
    }
    else if((df$fix_num[i]==1) & (df$fix_stim[i] != "weights")){
        df$which_fix[i] = 1
    }
    # if none of those then it is middle fixation, code = 2
    else {
        df$which_fix[i] = 2
    }
}

# %% [markdown]
# ### Add `fix_stim` weight and value for each fixation

# %%
df$fix_stim_val_base = 0
df$fix_stim_mult = 0

# %% [markdown]
# #### For Face/House

# %%
# go through each row and  (must be a better way...)
for (i in seq(dim(df)[1])) {
    
    # for weights fixations code = 0
    if (df$fix_stim[i] == "weights"){
        df$fix_stim_val_base[i] = 0
        df$fix_stim_mult[i] = 0
    }
    # for left stim = face
    else if (df$left[i] == 'face'){
        # if stim is left
        if (df$fix_stim[i] == 'left'){
            df$fix_stim_val_base[i] = df$face_val_base[i]
            df$fix_stim_mult[i] = df$face_mult[i]
        }
        # if stim is right
        else if (df$fix_stim[i] == 'right'){
            df$fix_stim_val_base[i] = df$house_val_base[i]
            df$fix_stim_mult[i] = df$house_mult[i]
        }
    }
    # if left stim = house
    else if (df$left[i] == 'house'){
        # if stim is left
        if (df$fix_stim[i] == 'left'){
            df$fix_stim_val_base[i] = df$house_val_base[i]
            df$fix_stim_mult[i] = df$house_mult[i]
        }
        # if stim is right
        else if (df$fix_stim[i] == 'right'){
            df$fix_stim_val_base[i] = df$face_val_base[i]
            df$fix_stim_mult[i] = df$face_mult[i]
        }
    }
}

# %% [markdown]
# #### For Unattractive/Attractive

# %%
# go through each row and  (must be a better way...)
for (i in seq(dim(df)[1])) {
    
    # for weights fixations code = 0
    if (df$fix_stim[i] == "weights"){
        df$fix_stim_val_base[i] = 0
        df$fix_stim_mult[i] = 0
    }
    # for left stim = unattractive
    else if (df$left[i] == 'unattractive'){
        # if stim is left
        if (df$fix_stim[i] == 'left'){
            df$fix_stim_val_base[i] = df$unattractive_face_val_base[i]
            df$fix_stim_mult[i] = df$unattractive_face_mult[i]
        }
        # if stim is right
        else if (df$fix_stim[i] == 'right'){
            df$fix_stim_val_base[i] = df$attractive_face_val_base[i]
            df$fix_stim_mult[i] = df$attractive_face_mult[i]
        }
    }
    # if left stim = house
    else if (df$left[i] == 'attractive'){
        # if stim is left
        if (df$fix_stim[i] == 'left'){
            df$fix_stim_val_base[i] = df$attractive_face_val_base[i]
            df$fix_stim_mult[i] = df$attractive_face_mult[i]
        }
        # if stim is right
        else if (df$fix_stim[i] == 'right'){
            df$fix_stim_val_base[i] = df$unattractive_face_val_base[i]
            df$fix_stim_mult[i] = df$unattractive_face_mult[i]
        }
    }
}

# %%
head(df)
# Out:
#   date             psychopy_version exp_version unattractive_face_version
# 1 2019_Jul_04_1013 3.0.2            3.3.0       0
# 2 2019_Jul_04_1013 3.0.2            3.3.0       0
# 3 2019_Jul_04_1013 3.0.2            3.3.0       0
# 4 2019_Jul_04_1013 3.0.2            3.3.0       0
# 5 2019_Jul_04_1013 3.0.2            3.3.0       0
# 6 2019_Jul_04_1013 3.0.2            3.3.0       0
#   attractive_face_version left         subject block trial rt     ⋯ fix_stim
# 1 1                       unattractive 201     0     0     10.767 ⋯ weights
# 2 1                       unattractive 201     0     0     10.767 ⋯ left
# 3 1                       unattractive 201     0     0     10.767 ⋯ weights
# 4 1                       unattractive 201     0     0     10.767 ⋯ right
# 5 1                       unattractive 201     0     0     10.767 ⋯ weights
# 6 1                       unattractive 201     0     0     10.767 ⋯ left
#   fix_num_total accuracy payout total_fix_num total_weights_fix total_stim_fix
# 1 15            1        50     15            8                 7
# 2 15            1        50     15            8                 7
# 3 15            1        50     15            8                 7
# 4 15            1        50     15            8                 7
# 5 15            1        50     15            8                 7
# 6 15            1        50     15            8                 7
#   which_fix fix_stim_val_base fix_stim_mult
# 1 0          0.00             0.0
# 2 1          0.82             0.5
# 3 0          0.00             0.0
# 4 2         -0.74             0.5
# 5 0          0.00             0.0
# 6 2          0.82             0.5

# %% [markdown]
# ## Add left/right/pull mult columns

# %%
names(df)
# Out:
#  [1] "date"                        "psychopy_version"
#  [3] "exp_version"                 "unattractive_face_version"
#  [5] "attractive_face_version"     "left"
#  [7] "subject"                     "block"
#  [9] "trial"                       "rt"
# [11] "response"                    "correct"
# [13] "summed_val_total"            "unattractive_face_image"
# [15] "unattractive_face_val_base"  "unattractive_face_mult"
# [17] "unattractive_face_val_total" "attractive_face_image"
# [19] "attractive_face_val_base"    "attractive_face_mult"
# [21] "attractive_face_val_total"   "fix_num"
# [23] "fix_rt"                      "fix_stim"
# [25] "fix_num_total"               "accuracy"
# [27] "payout"                      "total_fix_num"
# [29] "total_weights_fix"           "total_stim_fix"
# [31] "which_fix"                   "fix_stim_val_base"
# [33] "fix_stim_mult"

# %% [markdown]
# #### For Face/House

# %%
# initialize as if all 'left' stims are 'face'
df$left_mult = df$face_mult
df$right_mult = df$house_mult

# overwrite for those that are 'house'
df$left_mult[df$left=='house'] = df$house_mult[df$left=='house']
df$right_mult[df$left=='house'] = df$face_mult[df$left=='house']

# create value representing difference between left and right mults
df$left_mult_pull = df$left_mult - df$right_mult

# %% [markdown]
# #### For Unattractive/Attractive

# %%
# initialize as if all 'left' stims are 'attractive'
df$left_mult = df$attractive_face_mult
df$right_mult = df$unattractive_face_mult

# overwrite for those that are 'house'
df$left_mult[df$left=='unattractive'] = df$unattractive_face_mult[df$left=='unattractive']
df$right_mult[df$left=='unattractive'] = df$attractive_face_mult[df$left=='unattractive']

# create value representing difference between left and right mults
df$left_mult_pull = df$left_mult - df$right_mult

# %%
names(df)
# Out:
#  [1] "date"                        "psychopy_version"
#  [3] "exp_version"                 "unattractive_face_version"
#  [5] "attractive_face_version"     "left"
#  [7] "subject"                     "block"
#  [9] "trial"                       "rt"
# [11] "response"                    "correct"
# [13] "summed_val_total"            "unattractive_face_image"
# [15] "unattractive_face_val_base"  "unattractive_face_mult"
# [17] "unattractive_face_val_total" "attractive_face_image"
# [19] "attractive_face_val_base"    "attractive_face_mult"
# [21] "attractive_face_val_total"   "fix_num"
# [23] "fix_rt"                      "fix_stim"
# [25] "fix_num_total"               "accuracy"
# [27] "payout"                      "total_fix_num"
# [29] "total_weights_fix"           "total_stim_fix"
# [31] "which_fix"                   "fix_stim_val_base"
# [33] "fix_stim_mult"               "left_mult"
# [35] "right_mult"                  "left_mult_pull"

# %%
# test to see if things are looking right
# v301
df[100,c(6,16,20,32,33,34)]
df[6111,c(6,16,20,32,33,34)]
# Out:
#   left face_mult house_mult fix_stim_mult left_mult right_mult
# 1 face 3         10         0             3         10
#   left  face_mult house_mult fix_stim_mult left_mult right_mult
# 1 house 2         3          0             3         2

# %%
# test to see if things are looking right
# v302
df[100,c(6,16,20,33,34,35)]
df[6111,c(6,16,20,33,34,35)]
# Out:
#   left face_mult house_mult left_mult right_mult left_mult_pull
# 1 face 3         10         3         10         -7
#   left  face_mult house_mult left_mult right_mult left_mult_pull
# 1 house 2         3          3         2          1

# %%
# test to see if things are looking right
# v310
df[100,c(6,16,20,36,37,38)]
df[4300,c(6,16,20,36,37,38)]
# Out:
# Error: Positive column indexes in `[` must match number of columns:
# * `.data` has 34 columns
# * Position 4 equals 36
# * Position 5 equals 37
# * Position 6 equals 38
# Traceback:
#
# 1. df[100, c(6, 16, 20, 36, 37, 38)]
# 2. `[.grouped_df`(df, 100, c(6, 16, 20, 36, 37, 38))
# 3. NextMethod()
# 4. `[.tbl_df`(df, 100, c(6, 16, 20, 36, 37, 38))
# 5. check_names_df(j, x)
# 6. check_names_df_numeric(j, x)
# 7. abort(error_large_column_index(n, pos_too_large, j[pos_too_large]))

# %% [markdown]
# ---
# # Inspect Data
# ---

# %% [markdown]
# ### Plot RT
# ---

# %%
mean_median = df %>%
    filter(rt<10) %>% # get rid of super long rts
    group_by(correct) %>% # add condition for v310
    summarise(n = n(),
             median_rt = median(rt),
             mean_rt = mean(rt),
             )
mean_median
# Out:
#   correct n     median_rt mean_rt
# 1 0       10210 5.083     5.310963
# 2 1       73994 3.731     4.230269

# %%
# plot subject rts
x = df %>%
    filter(rt<10) %>% # get rid of super long rts
    group_by(subject, trial) %>%
    summarise(correct = mean(correct),
              rt = mean(rt))

# set size
options(repr.plot.width=7, repr.plot.height=5)
# all subjects
ggplot(x, aes(rt, fill=as.factor(correct), colour=as.factor(correct))) + 
    geom_histogram(aes(y=..density..), alpha=0.5) + 
    geom_density(alpha=0.5) +
    geom_vline(xintercept = median(x$rt[x$correct==0])) +
    geom_vline(xintercept = median(x$rt[x$correct==1])) +
    theme_minimal() +
      ggtitle("All Subject RTs")

# individual
options(repr.plot.width=6, repr.plot.height=9)
p <- ggplot(x, aes(rt)) + geom_histogram(aes(y=..density..), alpha=0.5) + geom_density()
p + facet_grid(rows = vars(subject)) +
    theme_minimal() +
      ggtitle("Individual Subject RTs")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %% [markdown]
# ### Plot Accuracy

# %%
df_acc = df %>%
    group_by(subject, trial) %>%
    summarise(correct = mean(correct), rt = mean(rt)) %>%
    group_by(subject) %>%
    summarise(rt_sd = sd(rt, na.rm=T),
              min_rt = min(rt),
              max_rt = max(rt),
              accuracy = mean(correct),
              mean_rt=mean(rt))

head(df_acc)
# Out:
#   subject rt_sd    min_rt max_rt accuracy  mean_rt
# 1 201     2.679835 0.900  30.283 0.8762376 3.334527
# 2 202     2.052760 1.083  17.667 0.8712871 3.158891
# 3 203     2.063742 0.383  17.083 0.8787129 3.715077
# 4 206     4.967620 1.700  37.833 0.8886139 6.921748
# 5 207     1.743391 1.484  20.317 0.9455446 3.446022
# 6 208     3.693470 0.517  39.100 0.8391089 3.711609

# %%
# set plot size
options(repr.plot.width=4, repr.plot.height=3)

# plot subject accuracy
ggplot(data = df_acc,aes(x = as.factor(subject),y = accuracy)) + 
  geom_point() + 
  #geom_line() +
  #geom_errorbar(aes(ymin = rt-rt_se,ymax = rt+rt_se)) + 
  labs(x = "Subjects", y = "Accuracy") +
  theme_minimal() +
  ggtitle("Subject Accuracy")
# Out:
# plot without title

# %% [markdown]
# # Clean

# %% [markdown]
# ### Identify subjects by Accuracy (low)

# %% [markdown]
# #### pVal of each subject based on accuracy

# %%
# get the pValue
df_acc$pVal = pnorm(df_acc$accuracy, mean = mean(df_acc$accuracy), sd = sd(df_acc$accuracy))

# it is cumulative, so for those greater than 0.5, subtract from 1
df_acc[df_acc$pVal>0.5,]$pVal = 1-df_acc[df_acc$pVal>0.5,]$pVal

# add Hause's median outlier detection for comparison
df_acc$outliers = outliersMAD(df_acc$accuracy, MADCutOff = 3, replaceOutliersWith = -999)

# look at the sorted pVals
head(df_acc[order(df_acc$pVal),], 5)

# add to original dataframe (there must be a better way to do this...)
df$outlier_accuracy_pVal = 0
df$outlier_accuracy_MAD = 0

for (sub in unique(df$subject)){
    df[df$subject == sub,]$outlier_accuracy_pVal = df_acc[df_acc$subject == sub,]$pVal
    df[df$subject == sub,]$outlier_accuracy_MAD = df_acc[df_acc$subject == sub,]$outliers
}
tail(df,3)
# Out:
# 0 outliers detected.
# Outliers replaced with -999
#   subject rt_sd    min_rt max_rt accuracy  mean_rt  pVal       outliers
# 1 207     1.743391 1.484  20.317 0.9455446 3.446022 0.02594682 0.95
# 2 236     3.239435 1.417  24.866 0.9405941 4.700074 0.03788895 0.94
# 3 218     4.539644 1.700  39.982 0.8366337 5.319139 0.03934670 0.84
# 4 208     3.693470 0.517  39.100 0.8391089 3.711609 0.04704819 0.84
# 5 246     2.997259 0.533  18.716 0.8440594 5.956124 0.06604819 0.84
#   date             psychopy_version exp_version unattractive_face_version
# 1 2019_Jul_29_1310 3.0.2            3.3.0       0
# 2 2019_Jul_29_1310 3.0.2            3.3.0       0
# 3 2019_Jul_29_1310 3.0.2            3.3.0       0
#   attractive_face_version left         subject block trial rt    ⋯
# 1 1                       unattractive 249     3     403   3.583 ⋯
# 2 1                       unattractive 249     3     403   3.583 ⋯
# 3 1                       unattractive 249     3     403   3.583 ⋯
#   total_weights_fix total_stim_fix which_fix fix_stim_val_base fix_stim_mult
# 1 5                 4              0          0.00             0.0
# 2 5                 4              3         -0.98             0.5
# 3 5                 4              0          0.00             0.0
#   left_mult right_mult left_mult_pull outlier_accuracy_pVal
# 1 2         0.5        1.5            0.3969937
# 2 2         0.5        1.5            0.3969937
# 3 2         0.5        1.5            0.3969937
#   outlier_accuracy_MAD
# 1 0.9
# 2 0.9
# 3 0.9

# %% [markdown]
# #### Bootstrap confidence interval

# %%
nRuns = 1000

bootMeanAccuracy <- function(df) {
  bootSample <- sample_n(df, dim(df)[1], replace = TRUE)
  return(mean(bootSample$accuracy))
}

bootMeans <- replicate(nRuns, bootMeanAccuracy(df_acc))

# %%
bootCI <- quantile(bootMeans, c(0.025, 0.975))
sprintf("bootstrap confidence limits:")
bootCI
# Out:
# [1] "bootstrap confidence limits:"
#      2.5%     97.5%
# 0.7668699 0.8653060

# %%
boot_df = as.data.frame(bootMeans)

# %%
ggplot(data = boot_df, aes(bootMeans)) +
    geom_density()
# Out:
# plot without title

# %% [markdown]
# ### Identify trials by RT (slow/fast)

# %%
df_rt = df %>%
    group_by(subject) %>%
    select(subject, trial, rt)

# %%
# add to original dataframe (there must be a better way to do this...)
df$outlier_rt_pVal = 0
df$outlier_rt_MAD = 0

# Note that the MADCutOff can be tweaked
for (sub in unique(df$subject)){
    df[df$subject == sub,]$outlier_rt_MAD = outliersMAD(df_rt[df_rt$subject == sub,]$rt,
                                                                   MADCutOff = 3,
                                                                   replaceOutliersWith = -999)    
    #df[df$subject == sub,]$outlier_rt_pVal = df_acc[df_acc$subject == sub,]$outliers
}
tail(df,3)
# Out:
# 294 outliers detected.
# Outliers replaced with -999
# 132 outliers detected.
# Outliers replaced with -999
# 142 outliers detected.
# Outliers replaced with -999
# 121 outliers detected.
# Outliers replaced with -999
# 153 outliers detected.
# Outliers replaced with -999
# 371 outliers detected.
# Outliers replaced with -999
# 303 outliers detected.
# Outliers replaced with -999
# 371 outliers detected.
# Outliers replaced with -999
# 200 outliers detected.
# Outliers replaced with -999
# 140 outliers detected.
# Outliers replaced with -999
# 272 outliers detected.
# Outliers replaced with -999
# 351 outliers detected.
# Outliers replaced with -999
# 554 outliers detected.
# Outliers replaced with -999
# 221 outliers detected.
# Outliers replaced with -999
# 143 outliers detected.
# Outliers replaced with -999
# 395 outliers detected.
# Outliers replaced with -999
# 181 outliers detected.
# Outliers replaced with -999
# 372 outliers detected.
# Outliers replaced with -999
# 87 outliers detected.
# Outliers replaced with -999
# 173 outliers detected.
# Outliers replaced with -999
# 587 outliers detected.
# Outliers replaced with -999
# 215 outliers detected.
# Outliers replaced with -999
# 273 outliers detected.
# Outliers replaced with -999
# 1112 outliers detected.
# Outliers replaced with -999
# 284 outliers detected.
# Outliers replaced with -999
# 127 outliers detected.
# Outliers replaced with -999
# 253 outliers detected.
# Outliers replaced with -999
# 297 outliers detected.
# Outliers replaced with -999
# 577 outliers detected.
# Outliers replaced with -999
#   date             psychopy_version exp_version unattractive_face_version
# 1 2019_Jul_29_1310 3.0.2            3.3.0       0
# 2 2019_Jul_29_1310 3.0.2            3.3.0       0
# 3 2019_Jul_29_1310 3.0.2            3.3.0       0
#   attractive_face_version left         subject block trial rt    ⋯ which_fix
# 1 1                       unattractive 249     3     403   3.583 ⋯ 0
# 2 1                       unattractive 249     3     403   3.583 ⋯ 3
# 3 1                       unattractive 249     3     403   3.583 ⋯ 0
#   fix_stim_val_base fix_stim_mult left_mult right_mult left_mult_pull
# 1  0.00             0.0           2         0.5        1.5
# 2 -0.98             0.5           2         0.5        1.5
# 3  0.00             0.0           2         0.5        1.5
#   outlier_accuracy_pVal outlier_accuracy_MAD outlier_rt_pVal outlier_rt_MAD
# 1 0.3969937             0.9                  0               3.58
# 2 0.3969937             0.9                  0               3.58
# 3 0.3969937             0.9                  0               3.58

# %%
# percent of trials that were removed overall

kept =  (1 - dim(filter(df, outlier_rt_MAD > -900))[1] / (dim(df)[1])) * 100
sprintf("MAD removed %.2f percent of trials", kept)
# Out:
# [1] "MAD removed 8.87 percent of trials"

# %%
# percent of trials kept by subject

# Unfiltered DF
x_all = df %>%
    group_by(subject) %>%
    summarise(kept = length(unique(trial)))

# Filtered DF
x = df %>%
    filter(outlier_rt_MAD > -900) %>% # get rid of outlier RTs
    group_by(subject) %>%
    summarise(kept = length(unique(trial)),
              maxRT = max(rt), 
              minRT = min(rt),
              meanRT = mean(rt),
              sdRT = sd(rt))

x$kept = x$kept / x_all$kept
x
# Out:
#    subject kept      maxRT  minRT meanRT   sdRT
# 1  201     0.9504950  7.917 0.900 3.266956 1.587799
# 2  202     0.9851485  9.100 1.083 3.740728 1.989537
# 3  203     0.9702970  8.650 0.383 3.808082 1.703431
# 4  206     0.9777228 20.083 1.700 7.402802 4.301005
# 5  207     0.9628713  6.583 1.484 3.358858 1.047818
# 6  208     0.9628713 10.083 0.517 3.930482 2.173405
# 7  209     0.9529703 10.350 1.550 4.338325 1.981903
# 8  210     0.9529703 12.433 0.333 4.850024 2.594129
# 9  213     0.9554455 10.216 1.683 4.485622 1.932059
# 10 216     0.9702970 12.116 2.218 5.333608 2.196161
# 11 217     0.9504950  9.783 0.600 3.872295 2.072435
# 12 218     0.9282178 10.766 1.700 4.677107 2.043975
# 13 219     0.9504950 12.532 2.212 5.202939 2.374776
# 14 220     0.9727723 10.533 1.450 4.249096 2.077490
# 15 221     0.9777228  6.617 1.383 3.183345 1.311427
# 16 222     0.9727723 22.266 0.983 7.790020 4.817917
# 17 224     0.9727723 10.500 0.667 4.077746 2.160124
# 18 225     0.9554455 13.866 0.417 5.572552 2.730512
# 19 226     0.9876238 24.100 1.483 8.267045 4.957321
# 20 230     0.9678218  9.433 0.550 3.970646 2.010587
# 21 231     0.9331683 12.183 0.367 4.792316 2.500662
# 22 232     0.9678218 10.766 1.134 4.316916 2.256378
# 23 233     0.9678218  9.219 1.526 4.206826 1.650255
# 24 234     0.9504950 26.123 0.336 8.113992 6.377374
# 25 236     0.9405941 11.300 1.417 4.579313 2.243695
# 26 237     0.9678218 11.683 0.833 4.757746 2.425754
# 27 246     0.9678218 13.550 0.533 6.185632 2.538487
# 28 248     0.9480198  7.707 0.341 3.338766 1.458139
# 29 249     0.9331683 11.383 1.366 4.378825 2.235884

# %%
# Plot
ggplot(x, aes(as.factor(subject), kept)) +
    geom_point()

# QUESTION: Remove some subjects if we keep below a certain percentage of trials?
# Out:
# plot without title

# %% [markdown]
# ---
# ### Remove Outlier subjects and trials

# %% [markdown]
# ---
# * remove low accuracy subjects
# * remove outlier RTs
# * remove subjects who had less than 50% non-outlier RTs
#
# ---

# %%
# v3.0.1
v301_clean = df %>%
    filter(outlier_accuracy_MAD > -900) %>% # get rid of outlier accuracy subjects
    filter(outlier_rt_MAD > -900) %>% # get rid of outlier RT trials
    filter(subject != 35) # remove subject with low non outlier RT trials

clean_sub = length(unique(v301_clean$subject))

sprintf("You are keeping %i out of %i total subjects.", clean_sub, length(unique(df_v301$subject)))
# Out:
# Error in unique(df_v301$subject): object 'df_v301' not found
# Traceback:
#
# 1. sprintf("You are keeping %i out of %i total subjects.", clean_sub,
#  .     length(unique(df_v301$subject)))
# 2. unique(df_v301$subject)

# %%
# v3.0.2
v302_clean = df %>%
    filter(outlier_accuracy_MAD > -900) %>% # get rid of outlier accuracy subjects
    filter(outlier_rt_MAD > -900) # get rid of outlier RT trials

clean_sub = length(unique(v302_clean$subject))

sprintf("You are keeping %i out of %i total subjects.", clean_sub, length(unique(df_v302$subject)))
# Out:
# [1] "You are keeping 23 out of 26 total subjects."

# %%
# v3.1.0
v310_clean = df %>%
    filter(outlier_accuracy_MAD > -900) %>% # get rid of outlier accuracy subjects
    filter(outlier_rt_MAD > -900) # get rid of outlier RT trials

clean_sub = length(unique(v310_clean$subject))

sprintf("You are keeping %i out of %i total subjects.", clean_sub, length(unique(df_v310$subject)))
# Out:
# [1] "You are keeping 28 out of 31 total subjects."

# %%
# v3.1.1
v311_clean = df %>%
    filter(outlier_accuracy_MAD > -900) %>% # get rid of outlier accuracy subjects
    filter(outlier_rt_MAD > -900) # get rid of outlier RT trials

clean_sub = length(unique(v311_clean$subject))

sprintf("You are keeping %i out of %i total subjects.", clean_sub, length(unique(df_v311$subject)))
# Out:
# [1] "You are keeping 35 out of 36 total subjects."

# %%
# v3.3.0
v330_clean = df %>%
    filter(outlier_accuracy_MAD > -900) %>% # get rid of outlier accuracy subjects
    filter(outlier_rt_MAD > -900) # get rid of outlier RT trials

clean_sub = length(unique(v330_clean$subject))

sprintf("You are keeping %i out of %i total subjects.", clean_sub, length(unique(v330_clean$subject)))
# Out:
# [1] "You are keeping 29 out of 29 total subjects."

# %% [markdown]
# # Export

# %% [markdown]
# ### Export DF

# %%
# v3.0.1
saveRDS(v301_clean, "data/v301_clean.rds")

# %%
# v3.0.2
saveRDS(v302_clean, "data/v302_clean.rds")

# %%
# v3.1.0
saveRDS(v310_clean, "data/v310_clean.rds")

# %%
# v3.1.1
saveRDS(v311_clean, "data/v311_clean.rds")

# %%
# v3.3.0
saveRDS(v330_clean, "data/v330_clean.rds")
saveRDS(df_v330_rating, "data/v330_rating.rds")
saveRDS(df_v330_recall, "data/v330_recall.rds")

# %% [markdown]
# # FUNCTIONS

# %%
#' @title Identify outliers using robust median absolute deviation approach
#' @name outliersMAD
#'
#' @description outliersMAD is used to identify outliers in vectors using Leys et al.'s (2003) median absolute deviation approach.
#'
#' @param x a vector of numbers
#' @param MADCutOff value to use as cutoff (Leys e tal. recommend 2.5 or 3.0 as default)
#' @param replaceOutliersWith if value is an outlier, what to replace it with? NA by default
#' @param showMADValues if TRUE, will show deviation score of each value
#' @param outlierIndices return index/position of outlier
#' @param bConstant a constant linked to the assumption of normality of the data, disregarding the abnormality induced by outliers
#' @param digits how many digits/decimals to round output to
#'
#' @return A vector with outliers identified (default converts outliers to NA)
#'
#' @details We can identify and remove outliers in our data by identifying data points that are too extreme—either too many standard deviations (SD) away from the mean or too many median absolute deviations (MAD) away from the median. The SD approach might not be ideal with extreme outliers, whereas the MAD approach is much more robust (for comparison of both approaches, see Leys et al., 2013, Journal of Experimental Social Psychology).
#'
#' @references \itemize{
#' \item Leys, C., Ley, C., Klein, O., Bernard, P., & Licata, L. (2013). Detecting outliers: Do not use standard deviation around the mean, use absolute deviation around the median. Journal of Experimental Social Psychology, 49(4), 764-766. doi:10.1016/j.jesp.2013.03.013 (\url{https://www.sciencedirect.com/science/article/pii/S0022103113000668})}
#' @seealso \code{\link{outliersZ}}
#'
#' @author Hause Lin
#'
#' @export
#'
#' @usage
#' outliersMAD(x, MADCutOff = 2.5, replaceOutliersWith = NA,
#' showMADValues = FALSE, outlierIndices = FALSE, bConstant = 1.4826, digits = 2)
#'
#' @examples
#' example <- c(1, 3, 3, 6, 8, 10, 10, 1000) # 1000 is an outlier
#' outliersMAD(example)
#' outliersMAD(example, MADCutOff = 3.0)
#' outliersMAD(example, MADCutOff = 2.5, replaceOutliersWith = -999)
#' outliersMAD(example, MADCutOff = 1.5, outlierIndices = TRUE)
#' outliersMAD(example, MADCutOff = 1.5, showMADValues = TRUE)
outliersMAD <- function(x, MADCutOff = 2.5, replaceOutliersWith = NA, showMADValues = FALSE, outlierIndices = FALSE, bConstant = 1.4826, digits = 2) {
  # bConstant: usually, b = 1.4826, a constant linked to the assumption of normality of the data, disregarding the abnormality induced by out- liers (Rousseeuw & Croux, 1993).

  # compute number of absolute MADs away for each value: formula: abs( ( x - median(x) ) )/ mad(x)
  absMADAway <- abs((x - stats::median(x, na.rm = T))/stats::mad(x, constant = bConstant, na.rm = T))
  # subset data that has absMADAway greater than the MADCutOff and replace them with replace
  x[absMADAway > MADCutOff] <- replaceOutliersWith
  outliers <- length(x[absMADAway > MADCutOff])
  if (showMADValues) { # if values == TRUE, return number of mads for each value
    message("Showing absolute MAD from median for each value.")
    message(paste0(outliers, " outliers detected."))
    return(round(absMADAway, digits))
  } else if (outlierIndices) {
    message("Showing indices of outliers.")
    return(which(is.na(x)))
  } else {
    message(paste0(outliers, " outliers detected."))
    message(paste0("Outliers replaced with ", replaceOutliersWith))
    return(round(x, digits)) # otherwise, return original with outliers replaced
  }
}
